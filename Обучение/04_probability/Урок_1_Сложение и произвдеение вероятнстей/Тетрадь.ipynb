# %%
white1 = 10
black1 = 4

white2 = 5
black2 = 9

P = round(black1/(white1+black1) * black2/(white2+black2),3)
P
# Out:
# 0.184

# %%
P_попасть_1_раз_из_4 = 0.9984
 
P_ни_разу_не_попасть = 1 - shoot_target_4

0.002**3
# Out:
# 8e-09

# %%
one = 3/10
two = 2/9
free = 1/8

one * two * free
# Out:
# 0.008333333333333333

# %%
robot1 = 2/3
robot2 = 2/3
robot3 = 2/3

total = 8

2/8
# Out:
# 0.25

# %%
A = 1/6
B = 6/36
С = 1/6

AB = A*B
2/36
# Out:
# 0.05555555555555555

# %%
round(19/36,3)
# Out:
# 0.528
